# %%
# !python -V
# Out:
# Python 3.9.23

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
import pickle
import sklearn
import numpy as np

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-eperiment")
# Out:
# 2025/12/11 06:45:20 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/12/11 06:45:20 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# <Experiment: artifact_location='/workspaces/Mlops_Zoom_camp/02-Experiment Tracking/mlruns/1', creation_time=1765408879095, experiment_id='1', last_update_time=1765408879095, lifecycle_stage='active', name='nyc-taxi-eperiment', tags={}>

# %%
def data_read_pre_processing(file_path):
    
   
    #reading the data from the defined path
    df = pd.read_parquet(file_path)
    
    #Converting the columns to timestamp
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    
    #Calculating duration of the trip
    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df['duration'] = df.duration.apply(lambda td: td.total_seconds()/60)
    
    #filetring the data 
    df = df[(df.duration>=1) & (df.duration<=60)]
    
    return df

# %%
df_train = data_read_pre_processing('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet')

df_val = data_read_pre_processing('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-02.parquet')

# %%
import sys, sklearn
print(sys.executable)
print(sklearn.__version__)
# Out:
# /home/codespace/anaconda3/envs/exp-tracking-env/bin/python
# 1.3.0

# %%
#### Created new Feature
df_train['PU_DO'] = df_train['PULocationID'].astype(str) + '_' + df_train['DOLocationID'].astype(str)
df_val['PU_DO']  = df_val['PULocationID'].astype(str)  + '_' + df_val['DOLocationID'].astype(str)

# %%
### defining the train set 
categorical = ['PU_DO']#['PULocationID','DOLocationID']
numerical = ['trip_distance']

### Converting categorical variable into string for preprocessing
df_train[categorical] = df_train[categorical].astype(str)
train_dicts = df_train[categorical+numerical].to_dict(orient = 'records') 

### Converting categorical variable into string for preprocessing
df_val[categorical] = df_val[categorical].astype(str)
val_dicts = df_val[categorical+numerical].to_dict(orient = 'records')

# %%
### Vectoriser
dv = DictVectorizer()

# %%
## vectorizing traing Features
X_train = dv.fit_transform(train_dicts)
X_train
# Out:
# <73908x13221 sparse matrix of type '<class 'numpy.float64'>'
# 	with 147816 stored elements in Compressed Sparse Row format>

# %%
## vectorizing validation Features
X_val = dv.transform(val_dicts)
X_val
# Out:
# <61921x13221 sparse matrix of type '<class 'numpy.float64'>'
# 	with 118585 stored elements in Compressed Sparse Row format>

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# prediting the values for train set
y_predict_train = lr.predict(X_train)

# prediting the values for train set
y_predict_val = lr.predict(X_val)

# %%
import inspect
inspect.signature(mean_squared_error)
# Out:
# <Signature (y_true, y_pred, *, sample_weight=None, multioutput='uniform_average', squared=True)>

# %%
rmse = np.sqrt(mean_squared_error(y_train,y_predict_train))
rmse
# Out:
# 5.699564118198979

# %%
rmse_val =  mean_squared_error(y_val,y_predict_val,squared = False)
rmse_val
# Out:
# 7.758715209663881

# %%
with open('models/lin_reg.bin','wb') as f_out:
    pickle.dump((dv,lr),f_out)

# %% [markdown]
# # Checking a different Model like LASSO or Ridge

# %%
with mlflow.start_run():

    mlflow.set_tag("developer","Tej")

    mlflow.log_param("train-data-url","https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet")
    mlflow.log_param("validation-data-url","https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-02.parquet")
    
    alpha =0.1
    mlflow.log_param("alpha",alpha)
    lr_new = Lasso(alpha)
    lr_new.fit(X_train,y_train)
    
    y_pred_new = lr_new.predict(X_val)
    rmse = mean_squared_error(y_val,y_pred_new,squared = False)
    mlflow.log_metric("rmse",rmse)
    mlflow.log_artifact(local_path = "models/lin_reg.bin", artifact_path = "models_pickle")

# %% [markdown]
# ## Performing Hyper Parameter Tuning and loggoing the best results in ML flow

# %%
import xgboost as xgb

from hyperopt import fmin,hp,tpe,STATUS_OK, Trials
from hyperopt.pyll import scope
# Out:
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/atpe.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
train = xgb.DMatrix(X_train,label = y_train)
valid = xgb.DMatrix(X_val,label = y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model","xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params =params,
            dtrain =train,
            num_boost_round =1000,
            evals=[(valid,"validation")],
            early_stopping_rounds = 50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val,y_pred,squared = False)
        mlflow.log_metric("rmse", rmse)

    return {"loss":rmse,'status':STATUS_OK}

# %%
search_space = {
    'max_depth' :scope.int(hp.quniform('max_depth',4,100,1)),
    'learning_rate' :hp.loguniform('learning_rate',-3,0),
    'reg_alpha' :hp.loguniform('reg_alpha',-5,-1),
    'reg_lambda' :hp.loguniform('reg_lambda',-6,-1),
    'min_child_weight' :hp.loguniform('min_child_weight',-1,3),
    'objective' :'reg:squarederror',
    'seed' : 42,
}

best_result =fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
    )
# Out:
# [0]	validation-rmse:8.57790
# [1]	validation-rmse:7.34225
# [2]	validation-rmse:6.95764
# [3]	validation-rmse:6.82958
# [4]	validation-rmse:6.77659
# [5]	validation-rmse:6.75972
# [6]	validation-rmse:6.74257
# [7]	validation-rmse:6.73711
# [8]	validation-rmse:6.73233
# [9]	validation-rmse:6.72589
# [10]	validation-rmse:6.72143
# [11]	validation-rmse:6.71771
# [12]	validation-rmse:6.71650
# [13]	validation-rmse:6.70858
# [14]	validation-rmse:6.70754
# [15]	validation-rmse:6.70684
# [16]	validation-rmse:6.70168
# [17]	validation-rmse:6.69908
# [18]	validation-rmse:6.69720
# [19]	validation-rmse:6.69451
# [20]	validation-rmse:6.69111
# [21]	validation-rmse:6.68833
# [22]	validation-rmse:6.68293
# [23]	validation-rmse:6.68167
# [24]	validation-rmse:6.67682
# [25]	validation-rmse:6.67254
# [26]	validation-rmse:6.67068
# [27]	validation-rmse:6.66903
# [28]	validation-rmse:6.66593
# [29]	validation-rmse:6.66359
# [30]	validation-rmse:6.66061
# [31]	validation-rmse:6.65655
# [32]	validation-rmse:6.65435
# [33]	validation-rmse:6.65187
# [34]	validation-rmse:6.64945
# [35]	validation-rmse:6.64737
# [36]	validation-rmse:6.64458
# [37]	validation-rmse:6.64305
# [38]	validation-rmse:6.64078
# [39]	validation-rmse:6.63926
# [40]	validation-rmse:6.63464
# [41]	validation-rmse:6.63429
# [42]	validation-rmse:6.63294
# [43]	validation-rmse:6.63269
# [44]	validation-rmse:6.63138
# [45]	validation-rmse:6.62814
# [46]	validation-rmse:6.62649
# [47]	validation-rmse:6.62513
# [48]	validation-rmse:6.62420
# [49]	validation-rmse:6.62423
# [50]	validation-rmse:6.62373
# [51]	validation-rmse:6.62275
# [52]	validation-rmse:6.62214
# [53]	validation-rmse:6.62100
# [54]	validation-rmse:6.62009
# [55]	validation-rmse:6.61964
# [56]	validation-rmse:6.61742
# [57]	validation-rmse:6.61495
# [58]	validation-rmse:6.61401
# [59]	validation-rmse:6.61302
# [60]	validation-rmse:6.61217
# [61]	validation-rmse:6.61026
# [62]	validation-rmse:6.60937
# [63]	validation-rmse:6.60790
# [64]	validation-rmse:6.60793
# [65]	validation-rmse:6.60641
# [66]	validation-rmse:6.60538
# [67]	validation-rmse:6.60290
# [68]	validation-rmse:6.60168
# [69]	validation-rmse:6.60085
# [70]	validation-rmse:6.60009
# [71]	validation-rmse:6.59898
# [72]	validation-rmse:6.59806
# [73]	validation-rmse:6.59690
# [74]	validation-rmse:6.59165
# [75]	validation-rmse:6.59077
# [76]	validation-rmse:6.58938
# [77]	validation-rmse:6.58757
# [78]	validation-rmse:6.58611
# [79]	validation-rmse:6.58468
# [80]	validation-rmse:6.58343
# [81]	validation-rmse:6.58100
# [82]	validation-rmse:6.57884
# [83]	validation-rmse:6.57774
# [84]	validation-rmse:6.57581
# [85]	validation-rmse:6.57298
# [86]	validation-rmse:6.57150
# [87]	validation-rmse:6.56878
# [88]	validation-rmse:6.56776
# [89]	validation-rmse:6.56561
# [90]	validation-rmse:6.56289
# [91]	validation-rmse:6.56172
# [92]	validation-rmse:6.56135
# [93]	validation-rmse:6.56026
# [94]	validation-rmse:6.55951
# [95]	validation-rmse:6.55876
# [96]	validation-rmse:6.55831
# [97]	validation-rmse:6.55651
# [98]	validation-rmse:6.55609
# [99]	validation-rmse:6.55525
# [100]	validation-rmse:6.55416
# [101]	validation-rmse:6.55258
# [102]	validation-rmse:6.55187
# [103]	validation-rmse:6.55037
# [104]	validation-rmse:6.54964
# [105]	validation-rmse:6.54849
# [106]	validation-rmse:6.54687
# [107]	validation-rmse:6.54623
# [108]	validation-rmse:6.54555
# [109]	validation-rmse:6.54425
# [110]	validation-rmse:6.54411
# [111]	validation-rmse:6.54361
# [112]	validation-rmse:6.54303
# [113]	validation-rmse:6.54242
# [114]	validation-rmse:6.54137
# [115]	validation-rmse:6.54068
# [116]	validation-rmse:6.53992
# [117]	validation-rmse:6.53900
# [118]	validation-rmse:6.53835
# [119]	validation-rmse:6.53704
# [120]	validation-rmse:6.53511
# [121]	validation-rmse:6.53461
# [122]	validation-rmse:6.53259
# [123]	validation-rmse:6.53196
# [124]	validation-rmse:6.53162
# [125]	validation-rmse:6.53081
# [126]	validation-rmse:6.52967
# [127]	validation-rmse:6.52799
# [128]	validation-rmse:6.52800
# [129]	validation-rmse:6.52764
# [130]	validation-rmse:6.52693
# [131]	validation-rmse:6.52578
# [132]	validation-rmse:6.52459
# [133]	validation-rmse:6.52371
# [134]	validation-rmse:6.52324
# [135]	validation-rmse:6.52196
# [136]	validation-rmse:6.52167
# [137]	validation-rmse:6.52118
# [138]	validation-rmse:6.52052
# [139]	validation-rmse:6.51947
# [140]	validation-rmse:6.51752
# [141]	validation-rmse:6.51492
# [142]	validation-rmse:6.51327
# [143]	validation-rmse:6.51181
# [144]	validation-rmse:6.51127
# [145]	validation-rmse:6.51116
# [146]	validation-rmse:6.51066
# [147]	validation-rmse:6.51030
# [148]	validation-rmse:6.50998
# [149]	validation-rmse:6.50845
# [150]	validation-rmse:6.50720
# [151]	validation-rmse:6.50708
# [152]	validation-rmse:6.50550
# [153]	validation-rmse:6.50448
# [154]	validation-rmse:6.50396
# [155]	validation-rmse:6.50318
# [156]	validation-rmse:6.50280
# [157]	validation-rmse:6.50213
# [158]	validation-rmse:6.50168
# [159]	validation-rmse:6.50071
# [160]	validation-rmse:6.49909
# [161]	validation-rmse:6.49892
# [162]	validation-rmse:6.49901
# [163]	validation-rmse:6.49840
# [164]	validation-rmse:6.49778
# [165]	validation-rmse:6.49634
# [166]	validation-rmse:6.49598
# [167]	validation-rmse:6.49493
# [168]	validation-rmse:6.49406
# [169]	validation-rmse:6.49357
# [170]	validation-rmse:6.49321
# [171]	validation-rmse:6.49276
# [172]	validation-rmse:6.49125
# [173]	validation-rmse:6.49088
# [174]	validation-rmse:6.49057
# [175]	validation-rmse:6.49032
# [176]	validation-rmse:6.48931
# [177]	validation-rmse:6.48816
# [178]	validation-rmse:6.48778
# [179]	validation-rmse:6.48799
# [180]	validation-rmse:6.48680
# [181]	validation-rmse:6.48646
# [182]	validation-rmse:6.48651
# [183]	validation-rmse:6.48583
# [184]	validation-rmse:6.48531
# [185]	validation-rmse:6.48454
# [186]	validation-rmse:6.48416
# [187]	validation-rmse:6.48367
# [188]	validation-rmse:6.48293
# [189]	validation-rmse:6.48219
# [190]	validation-rmse:6.48181
# [191]	validation-rmse:6.48118
# [192]	validation-rmse:6.48028
# [193]	validation-rmse:6.48071
# [194]	validation-rmse:6.47743
# [195]	validation-rmse:6.47657
# [196]	validation-rmse:6.47650
# [197]	validation-rmse:6.47611
# [198]	validation-rmse:6.47588
# [199]	validation-rmse:6.47546
# [200]	validation-rmse:6.47575
# [201]	validation-rmse:6.47556
# [202]	validation-rmse:6.47386
# [203]	validation-rmse:6.47251
# [204]	validation-rmse:6.47208
# [205]	validation-rmse:6.47115
# [206]	validation-rmse:6.47119
# [207]	validation-rmse:6.47073
# [208]	validation-rmse:6.46981
# [209]	validation-rmse:6.46901
# [210]	validation-rmse:6.46818
# [211]	validation-rmse:6.46744
# [212]	validation-rmse:6.46651
# [213]	validation-rmse:6.46580
# [214]	validation-rmse:6.46501
# [215]	validation-rmse:6.46467
# [216]	validation-rmse:6.46406
# [217]	validation-rmse:6.46410
# [218]	validation-rmse:6.46392
# [219]	validation-rmse:6.46412
# [220]	validation-rmse:6.46290
# [221]	validation-rmse:6.46253
# [222]	validation-rmse:6.46235
# [223]	validation-rmse:6.46205
# [224]	validation-rmse:6.46129
# [225]	validation-rmse:6.46046
# [226]	validation-rmse:6.45985
# [227]	validation-rmse:6.45887
# [228]	validation-rmse:6.45834
# [229]	validation-rmse:6.45776
# [230]	validation-rmse:6.45788
# [231]	validation-rmse:6.45768
# [232]	validation-rmse:6.45785
# [233]	validation-rmse:6.45773
# [234]	validation-rmse:6.45701
# [235]	validation-rmse:6.45643
# ...
# [943]	validation-rmse:6.31741
# [944]	validation-rmse:6.31637
# [0]	validation-rmse:10.85308
# [1]	validation-rmse:9.79870
# [2]	validation-rmse:8.99076
# [3]	validation-rmse:8.37970
# [4]	validation-rmse:7.92208
# [5]	validation-rmse:7.58219
# [6]	validation-rmse:7.33154
# [7]	validation-rmse:7.14602
# [8]	validation-rmse:7.00680
# [9]	validation-rmse:6.90227
# [10]	validation-rmse:6.82570
# [11]	validation-rmse:6.76712
# [12]	validation-rmse:6.72308
# [13]	validation-rmse:6.68874
# [14]	validation-rmse:6.66048
# [15]	validation-rmse:6.63856
# [16]	validation-rmse:6.62244
# [17]	validation-rmse:6.60894
# [18]	validation-rmse:6.59729
# [19]	validation-rmse:6.58639
# [20]	validation-rmse:6.57820
# [21]	validation-rmse:6.57107
# [22]	validation-rmse:6.56507
# [23]	validation-rmse:6.56024
# [24]	validation-rmse:6.55258
# [25]	validation-rmse:6.54820
# [26]	validation-rmse:6.54246
# [27]	validation-rmse:6.53910
# [28]	validation-rmse:6.53403
# [29]	validation-rmse:6.53159
# [30]	validation-rmse:6.52999
# [31]	validation-rmse:6.52716
# [32]	validation-rmse:6.52566
# [33]	validation-rmse:6.52497
# [34]	validation-rmse:6.52375
# [35]	validation-rmse:6.52287
# [36]	validation-rmse:6.52015
# [37]	validation-rmse:6.51838
# [38]	validation-rmse:6.51750
# [39]	validation-rmse:6.51655
# [40]	validation-rmse:6.51562
# [41]	validation-rmse:6.51517
# [42]	validation-rmse:6.51442
# [43]	validation-rmse:6.51334
# [44]	validation-rmse:6.51251
# [45]	validation-rmse:6.51201
# [46]	validation-rmse:6.51082
# [47]	validation-rmse:6.50998
# [48]	validation-rmse:6.50924
# [49]	validation-rmse:6.50819
# [50]	validation-rmse:6.50767
# [51]	validation-rmse:6.50698
# [52]	validation-rmse:6.50648
# [53]	validation-rmse:6.50582
# [54]	validation-rmse:6.50488
# [55]	validation-rmse:6.50475
# [56]	validation-rmse:6.50409
# [57]	validation-rmse:6.50372
# [58]	validation-rmse:6.50306
# [59]	validation-rmse:6.50191
# [60]	validation-rmse:6.50153
# [61]	validation-rmse:6.50099
# [62]	validation-rmse:6.49965
# [63]	validation-rmse:6.49936
# [64]	validation-rmse:6.49885
# [65]	validation-rmse:6.49807
# [66]	validation-rmse:6.49779
# [67]	validation-rmse:6.49701
# [68]	validation-rmse:6.49666
# [69]	validation-rmse:6.49646
# [70]	validation-rmse:6.49596
# [71]	validation-rmse:6.49564
# [72]	validation-rmse:6.49535
# [73]	validation-rmse:6.49494
# [74]	validation-rmse:6.49449
#   2%|██▋                                                                                                                                  | 1/50 [01:38<54:48, 67.11s/trial, best loss: 6.316366582223308]

# %%
import os, pickle
with mlflow.start_run():

    best_params = {
    "learning_rate" : 0.1832607471256377,
    "max_depth" : 53,
    "min_child_weight" : 1.5248259426208242,
    "objective" : "reg:squarederror",
    "reg_alpha" : 0.03914337949093102,
    "reg_lambda" : 0.20458604590859147,
    "seed" : 42,
    }
    mlflow.log_params(best_params)
    booster = xgb.train(
            params =best_params,
            dtrain =train,
            num_boost_round =10,
            evals=[(valid,"validation")],
            early_stopping_rounds = 50
        )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val,y_pred,squared = False)
    mlflow.log_metric("rmse", rmse)
    os.makedirs("models", exist_ok=True)
    with open('models/preprocessor.b','wb') as f_out:
       pickle.dump(dv,f_out)
    mlflow.log_artifact("models/preprocessor.b",artifact_path = "preprocessor")
    
    mlflow.xgboost.log_model(booster,name="xgb_model")
# Out:
# [0]	validation-rmse:10.74801
# [1]	validation-rmse:9.63418
# [2]	validation-rmse:8.79797
# [3]	validation-rmse:8.17701
# [4]	validation-rmse:7.72271
# [5]	validation-rmse:7.39379
# [6]	validation-rmse:7.15383
# [7]	validation-rmse:6.98266
# [8]	validation-rmse:6.85603
# [9]	validation-rmse:6.76075
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [07:36:58] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
# 2025/12/11 07:37:00 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
