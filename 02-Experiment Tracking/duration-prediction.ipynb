# %%
# !python -V
# Out:
# Python 3.9.23

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
import pickle
import sklearn
import numpy as np

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_registry_uri("sqlite:///mlflow.db")
mlflow.set_experiment("taxi-exp-2")
# Out:
# 2025/12/12 04:16:27 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/12/12 04:16:27 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2025/12/12 04:16:27 INFO mlflow.tracking.fluent: Experiment with name 'taxi-exp-2' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/workspaces/Mlops_Zoom_camp/02-Experiment Tracking/mlruns/1', creation_time=1765512987112, experiment_id='1', last_update_time=1765512987112, lifecycle_stage='active', name='taxi-exp-2', tags={}>

# %%
def data_read_pre_processing(file_path):
    
   
    #reading the data from the defined path
    df = pd.read_parquet(file_path)
    
    #Converting the columns to timestamp
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    
    #Calculating duration of the trip
    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df['duration'] = df.duration.apply(lambda td: td.total_seconds()/60)
    
    #filetring the data 
    df = df[(df.duration>=1) & (df.duration<=60)]
    
    return df

# %%
df_train = data_read_pre_processing('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet')

df_val = data_read_pre_processing('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-02.parquet')

# %%
import sys, sklearn
print(sys.executable)
print(sklearn.__version__)
# Out:
# /home/codespace/anaconda3/envs/exp-tracking-env/bin/python
# 1.3.0

# %%
#### Created new Feature
df_train['PU_DO'] = df_train['PULocationID'].astype(str) + '_' + df_train['DOLocationID'].astype(str)
df_val['PU_DO']  = df_val['PULocationID'].astype(str)  + '_' + df_val['DOLocationID'].astype(str)

# %%
### defining the train set 
categorical = ['PU_DO']#['PULocationID','DOLocationID']
numerical = ['trip_distance']

### Converting categorical variable into string for preprocessing
df_train[categorical] = df_train[categorical].astype(str)
train_dicts = df_train[categorical+numerical].to_dict(orient = 'records') 

### Converting categorical variable into string for preprocessing
df_val[categorical] = df_val[categorical].astype(str)
val_dicts = df_val[categorical+numerical].to_dict(orient = 'records')

# %%
### Vectoriser
dv = DictVectorizer()

# %%
## vectorizing traing Features
X_train = dv.fit_transform(train_dicts)
X_train
# Out:
# <73908x13221 sparse matrix of type '<class 'numpy.float64'>'
# 	with 147816 stored elements in Compressed Sparse Row format>

# %%
## vectorizing validation Features
X_val = dv.transform(val_dicts)
X_val
# Out:
# <61921x13221 sparse matrix of type '<class 'numpy.float64'>'
# 	with 118585 stored elements in Compressed Sparse Row format>

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# prediting the values for train set
y_predict_train = lr.predict(X_train)

# prediting the values for train set
y_predict_val = lr.predict(X_val)

# %%
import inspect
inspect.signature(mean_squared_error)
# Out:
# <Signature (y_true, y_pred, *, sample_weight=None, multioutput='uniform_average', squared=True)>

# %%
rmse = np.sqrt(mean_squared_error(y_train,y_predict_train))
rmse
# Out:
# 5.699564118198979

# %%
rmse_val =  mean_squared_error(y_val,y_predict_val,squared = False)
rmse_val
# Out:
# 7.758715209663881

# %%
with open('models/lin_reg.bin','wb') as f_out:
    pickle.dump((dv,lr),f_out)

# %% [markdown]
# # Checking a different Model like LASSO or Ridge

# %%
with mlflow.start_run():

    mlflow.set_tag("developer","Tej")

    mlflow.log_param("train-data-url","https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet")
    mlflow.log_param("validation-data-url","https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-02.parquet")
    
    alpha =0.1
    mlflow.log_param("alpha",alpha)
    lr_new = Lasso(alpha)
    lr_new.fit(X_train,y_train)
    
    y_pred_new = lr_new.predict(X_val)
    rmse = mean_squared_error(y_val,y_pred_new,squared = False)
    mlflow.log_metric("rmse",rmse)
    mlflow.log_artifact(local_path = "models/lin_reg.bin", artifact_path = "models_pickle")

# %% [markdown]
# ## Performing Hyper Parameter Tuning and loggoing the best results in ML flow

# %%
import xgboost as xgb

from hyperopt import fmin,hp,tpe,STATUS_OK, Trials
from hyperopt.pyll import scope
# Out:
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/atpe.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
train = xgb.DMatrix(X_train,label = y_train)
valid = xgb.DMatrix(X_val,label = y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model","xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params =params,
            dtrain =train,
            num_boost_round =10,
            evals=[(valid,"validation")],
            early_stopping_rounds = 50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val,y_pred,squared = False)
        mlflow.log_metric("rmse", rmse)

    return {"loss":rmse,'status':STATUS_OK}

# %%
search_space = {
    'max_depth' :scope.int(hp.quniform('max_depth',4,100,1)),
    'learning_rate' :hp.loguniform('learning_rate',-3,0),
    'reg_alpha' :hp.loguniform('reg_alpha',-5,-1),
    'reg_lambda' :hp.loguniform('reg_lambda',-6,-1),
    'min_child_weight' :hp.loguniform('min_child_weight',-1,3),
    'objective' :'reg:squarederror',
    'seed' : 42,
}

best_result =fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
    )
# Out:
# [0]	validation-rmse:9.79191
# [1]	validation-rmse:8.35911
# [2]	validation-rmse:7.54750
# [3]	validation-rmse:7.10020
# [4]	validation-rmse:6.85178
# [5]	validation-rmse:6.71376
# [6]	validation-rmse:6.63200
# [7]	validation-rmse:6.58205
# [8]	validation-rmse:6.54880
# [9]	validation-rmse:6.52814
# [0]	validation-rmse:7.55420
# [1]	validation-rmse:6.72448
# [2]	validation-rmse:6.55864
# [3]	validation-rmse:6.51065
# [4]	validation-rmse:6.49602
# [5]	validation-rmse:6.48633
# [6]	validation-rmse:6.48108
# [7]	validation-rmse:6.47248
# [8]	validation-rmse:6.46690
# [9]	validation-rmse:6.46371
# [0]	validation-rmse:10.54336
# [1]	validation-rmse:9.33914
# [2]	validation-rmse:8.48767
# [3]	validation-rmse:7.89751
# [4]	validation-rmse:7.49103
# [5]	validation-rmse:7.21589
# [6]	validation-rmse:7.02732
# [7]	validation-rmse:6.89960
# [8]	validation-rmse:6.81005
# [9]	validation-rmse:6.74754
# [0]	validation-rmse:10.40224
# [1]	validation-rmse:9.15816
# [2]	validation-rmse:8.32254
# [3]	validation-rmse:7.77439
# [4]	validation-rmse:7.41590
# [5]	validation-rmse:7.18606
# [6]	validation-rmse:7.03786
# [7]	validation-rmse:6.93822
# [8]	validation-rmse:6.87181
# [9]	validation-rmse:6.82657
# [0]	validation-rmse:7.99483
# [1]	validation-rmse:6.98820
# [2]	validation-rmse:6.75438
# [3]	validation-rmse:6.67731
# [4]	validation-rmse:6.64252
# [5]	validation-rmse:6.62812
# [6]	validation-rmse:6.61927
# [7]	validation-rmse:6.61190
# [8]	validation-rmse:6.60592
# [9]	validation-rmse:6.59908
# [0]	validation-rmse:9.10166
# [1]	validation-rmse:7.69640
# [2]	validation-rmse:7.10171
# [3]	validation-rmse:6.85019
# [4]	validation-rmse:6.73492
# [5]	validation-rmse:6.67991
# [6]	validation-rmse:6.64814
# [7]	validation-rmse:6.62656
# [8]	validation-rmse:6.61287
# [9]	validation-rmse:6.59862
# [0]	validation-rmse:10.45664
# [1]	validation-rmse:9.21422
# [2]	validation-rmse:8.35511
# [3]	validation-rmse:7.77052
# [4]	validation-rmse:7.37648
# [5]	validation-rmse:7.11396
# [6]	validation-rmse:6.93564
# [7]	validation-rmse:6.81811
# [8]	validation-rmse:6.73330
# [9]	validation-rmse:6.67613
# [0]	validation-rmse:11.30587
# [1]	validation-rmse:10.52950
# [2]	validation-rmse:9.86785
# [3]	validation-rmse:9.30697
# [4]	validation-rmse:8.83464
# [5]	validation-rmse:8.43656
# [6]	validation-rmse:8.10347
# [7]	validation-rmse:7.82696
# [8]	validation-rmse:7.59664
# [9]	validation-rmse:7.40670
# [0]	validation-rmse:11.50403
# [1]	validation-rmse:10.87728
# [2]	validation-rmse:10.32518
# [3]	validation-rmse:9.84029
# [4]	validation-rmse:9.41535
# [5]	validation-rmse:9.04443
# [6]	validation-rmse:8.72228
# [7]	validation-rmse:8.44233
# [8]	validation-rmse:8.19980
# [9]	validation-rmse:7.99081
# [0]	validation-rmse:8.75487
# [1]	validation-rmse:7.39915
# [2]	validation-rmse:6.90559
# [3]	validation-rmse:6.71592
# [4]	validation-rmse:6.62887
# [5]	validation-rmse:6.58498
# [6]	validation-rmse:6.55854
# [7]	validation-rmse:6.54280
# [8]	validation-rmse:6.52446
# [9]	validation-rmse:6.51910
# [0]	validation-rmse:8.13164
# [1]	validation-rmse:6.98603
# [2]	validation-rmse:6.67414
# [3]	validation-rmse:6.57964
# [4]	validation-rmse:6.53741
# [5]	validation-rmse:6.51433
# [6]	validation-rmse:6.50329
# [7]	validation-rmse:6.49650
# [8]	validation-rmse:6.49094
# [9]	validation-rmse:6.48656
# [0]	validation-rmse:9.16149
# [1]	validation-rmse:7.69762
# [2]	validation-rmse:7.04440
# [3]	validation-rmse:6.75539
# [4]	validation-rmse:6.61511
# [5]	validation-rmse:6.54323
# [6]	validation-rmse:6.50605
# [7]	validation-rmse:6.48233
# [8]	validation-rmse:6.46537
# [9]	validation-rmse:6.45656
# [0]	validation-rmse:11.56838
# [1]	validation-rmse:10.99191
# [2]	validation-rmse:10.47791
# [3]	validation-rmse:10.02122
# [4]	validation-rmse:9.61582
# [5]	validation-rmse:9.25738
# [6]	validation-rmse:8.94111
# [7]	validation-rmse:8.66281
# [8]	validation-rmse:8.41823
# [9]	validation-rmse:8.20377
# [0]	validation-rmse:7.62187
# [1]	validation-rmse:6.82804
# [2]	validation-rmse:6.67476
# [3]	validation-rmse:6.62863
# [4]	validation-rmse:6.60960
# [5]	validation-rmse:6.60166
# [6]	validation-rmse:6.59385
# [7]	validation-rmse:6.58367
# [8]	validation-rmse:6.57154
# [9]	validation-rmse:6.56707
# [0]	validation-rmse:9.89341
# [1]	validation-rmse:8.47156
# [2]	validation-rmse:7.63119
# [3]	validation-rmse:7.15086
# [4]	validation-rmse:6.87418
# [5]	validation-rmse:6.71796
# [6]	validation-rmse:6.62193
# [7]	validation-rmse:6.56117
# [8]	validation-rmse:6.52543
# [9]	validation-rmse:6.49883
# [0]	validation-rmse:11.20893
# [1]	validation-rmse:10.37168
# [2]	validation-rmse:9.67829
# [3]	validation-rmse:9.10744
# [4]	validation-rmse:8.64120
# [5]	validation-rmse:8.26186
# [6]	validation-rmse:7.95524
# [7]	validation-rmse:7.70837
# [8]	validation-rmse:7.50998
# [9]	validation-rmse:7.35044
# [0]	validation-rmse:7.31720
# [1]	validation-rmse:6.79079
# [2]	validation-rmse:6.70145
# [3]	validation-rmse:6.67676
# [4]	validation-rmse:6.66280
# [5]	validation-rmse:6.65481
# [6]	validation-rmse:6.64834
# [7]	validation-rmse:6.63874
# [8]	validation-rmse:6.62712
# [9]	validation-rmse:6.62124
# [0]	validation-rmse:11.36738
# [1]	validation-rmse:10.63761
# [2]	validation-rmse:10.01084
# [3]	validation-rmse:9.47336
# [4]	validation-rmse:9.01302
# [5]	validation-rmse:8.62985
# [6]	validation-rmse:8.29974
# [7]	validation-rmse:8.01947
# [8]	validation-rmse:7.78838
# [9]	validation-rmse:7.59109
# [0]	validation-rmse:7.65838
# [1]	validation-rmse:6.77032
# [2]	validation-rmse:6.58949
# [3]	validation-rmse:6.52580
# [4]	validation-rmse:6.50222
# [5]	validation-rmse:6.48637
# [6]	validation-rmse:6.47607
# [7]	validation-rmse:6.46931
# [8]	validation-rmse:6.46227
# [9]	validation-rmse:6.45681
# [0]	validation-rmse:6.79691
# [1]	validation-rmse:6.63880
# [2]	validation-rmse:6.60553
# [3]	validation-rmse:6.59429
# [4]	validation-rmse:6.58575
# [5]	validation-rmse:6.58242
# [6]	validation-rmse:6.57607
# [7]	validation-rmse:6.57011
# [8]	validation-rmse:6.56902
# [9]	validation-rmse:6.56599
# [0]	validation-rmse:9.21502
# [1]	validation-rmse:7.74576
# [2]	validation-rmse:7.07525
# [3]	validation-rmse:6.76908
# [4]	validation-rmse:6.63064
# [5]	validation-rmse:6.55597
# [6]	validation-rmse:6.51318
# [7]	validation-rmse:6.48630
# [8]	validation-rmse:6.47119
# [9]	validation-rmse:6.46137
# [0]	validation-rmse:6.67043
# [1]	validation-rmse:6.54203
# [2]	validation-rmse:6.51525
# [3]	validation-rmse:6.49596
# [4]	validation-rmse:6.48267
# [5]	validation-rmse:6.46539
# [6]	validation-rmse:6.45614
# [7]	validation-rmse:6.44903
# [8]	validation-rmse:6.44543
# [9]	validation-rmse:6.43629
# [0]	validation-rmse:10.93968
# [1]	validation-rmse:9.93376
# [2]	validation-rmse:9.14643
# [3]	validation-rmse:8.53620
# [4]	validation-rmse:8.06835
# [5]	validation-rmse:7.71416
# [6]	validation-rmse:7.44473
# [7]	validation-rmse:7.24171
# [8]	validation-rmse:7.08792
# [9]	validation-rmse:6.97128
# [0]	validation-rmse:11.79648
# [1]	validation-rmse:11.40762
# [2]	validation-rmse:11.04630
# [3]	validation-rmse:10.70911
# [4]	validation-rmse:10.39562
# [5]	validation-rmse:10.10262
# ...
# [3]	validation-rmse:10.08106
# [4]	validation-rmse:9.68153
# [5]	validation-rmse:9.32619
# [6]	validation-rmse:9.01114
# [7]	validation-rmse:8.73210
# [8]	validation-rmse:8.48547
# [9]	validation-rmse:8.26806
# [0]	validation-rmse:10.11410
# [1]	validation-rmse:8.76705
# [2]	validation-rmse:7.93095
# [3]	validation-rmse:7.41491
# [4]	validation-rmse:7.10499
# [5]	validation-rmse:6.91576
# [6]	validation-rmse:6.79437
# [7]	validation-rmse:6.71134
# [8]	validation-rmse:6.66532
# [9]	validation-rmse:6.63370
# [0]	validation-rmse:8.79973
# [1]	validation-rmse:7.41992
# [2]	validation-rmse:6.90233
# [3]	validation-rmse:6.69872
# [4]	validation-rmse:6.61115
# [5]	validation-rmse:6.56433
# [6]	validation-rmse:6.53696
# [7]	validation-rmse:6.52226
# [8]	validation-rmse:6.50420
# [9]	validation-rmse:6.49419
# [0]	validation-rmse:7.98414
# [1]	validation-rmse:6.92825
# [2]	validation-rmse:6.67418
# [3]	validation-rmse:6.59688
# [4]	validation-rmse:6.56590
# [5]	validation-rmse:6.55259
# [6]	validation-rmse:6.54263
# [7]	validation-rmse:6.53242
# [8]	validation-rmse:6.52603
# [9]	validation-rmse:6.51803
# [0]	validation-rmse:10.49226
# [1]	validation-rmse:9.26950
# [2]	validation-rmse:8.41767
# [3]	validation-rmse:7.83601
# [4]	validation-rmse:7.44522
# [5]	validation-rmse:7.18274
# [6]	validation-rmse:7.00397
# [7]	validation-rmse:6.88197
# [8]	validation-rmse:6.79308
# [9]	validation-rmse:6.73240
# [0]	validation-rmse:6.81789
# [1]	validation-rmse:6.53386
# [2]	validation-rmse:6.50557
# [3]	validation-rmse:6.49738
# [4]	validation-rmse:6.48437
# [5]	validation-rmse:6.47552
# [6]	validation-rmse:6.46830
# [7]	validation-rmse:6.46042
# [8]	validation-rmse:6.45240
# [9]	validation-rmse:6.44746
# [0]	validation-rmse:9.46633
# [1]	validation-rmse:8.03060
# [2]	validation-rmse:7.32746
# [3]	validation-rmse:6.98143
# [4]	validation-rmse:6.80844
# [5]	validation-rmse:6.72107
# [6]	validation-rmse:6.67432
# [7]	validation-rmse:6.64563
# [8]	validation-rmse:6.62785
# [9]	validation-rmse:6.61624
# [0]	validation-rmse:8.82508
# [1]	validation-rmse:7.49105
# [2]	validation-rmse:7.00164
# [3]	validation-rmse:6.82157
# [4]	validation-rmse:6.73542
# [5]	validation-rmse:6.69667
# [6]	validation-rmse:6.67134
# [7]	validation-rmse:6.65479
# [8]	validation-rmse:6.64055
# [9]	validation-rmse:6.63256
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [11:59<00:00, 14.40s/trial, best loss: 6.430137424348037]

# %%
import os, pickle
with mlflow.start_run():

    best_params = {
    "learning_rate" : 0.1832607471256377,
    "max_depth" : 53,
    "min_child_weight" : 1.5248259426208242,
    "objective" : "reg:squarederror",
    "reg_alpha" : 0.03914337949093102,
    "reg_lambda" : 0.20458604590859147,
    "seed" : 42,
    }
    mlflow.log_params(best_params)
    booster = xgb.train(
            params =best_params,
            dtrain =train,
            num_boost_round =100,
            evals=[(valid,"validation")],
            early_stopping_rounds = 50
        )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val,y_pred,squared = False)
    mlflow.log_metric("rmse", rmse)
    #os.makedirs("models", exist_ok=True)
    with open('models/preprocessor.b','wb') as f_out:
       pickle.dump(dv,f_out)
    mlflow.log_artifact("models/preprocessor.b",artifact_path = "preprocessor")
    
    mlflow.xgboost.log_model(booster,name="xgb_model")
# Out:
# [0]	validation-rmse:10.74801
# [1]	validation-rmse:9.63418
# [2]	validation-rmse:8.79797
# [3]	validation-rmse:8.17701
# [4]	validation-rmse:7.72271
# [5]	validation-rmse:7.39379
# [6]	validation-rmse:7.15383
# [7]	validation-rmse:6.98266
# [8]	validation-rmse:6.85603
# [9]	validation-rmse:6.76075
# [10]	validation-rmse:6.69187
# [11]	validation-rmse:6.63994
# [12]	validation-rmse:6.60079
# [13]	validation-rmse:6.57000
# [14]	validation-rmse:6.54547
# [15]	validation-rmse:6.52617
# [16]	validation-rmse:6.51044
# [17]	validation-rmse:6.49776
# [18]	validation-rmse:6.48631
# [19]	validation-rmse:6.47826
# [20]	validation-rmse:6.47111
# [21]	validation-rmse:6.46375
# [22]	validation-rmse:6.45912
# [23]	validation-rmse:6.45605
# [24]	validation-rmse:6.45350
# [25]	validation-rmse:6.45021
# [26]	validation-rmse:6.44861
# [27]	validation-rmse:6.44696
# [28]	validation-rmse:6.44587
# [29]	validation-rmse:6.44487
# [30]	validation-rmse:6.44381
# [31]	validation-rmse:6.44071
# [32]	validation-rmse:6.43863
# [33]	validation-rmse:6.43708
# [34]	validation-rmse:6.43479
# [35]	validation-rmse:6.43274
# [36]	validation-rmse:6.43126
# [37]	validation-rmse:6.42987
# [38]	validation-rmse:6.42827
# [39]	validation-rmse:6.42734
# [40]	validation-rmse:6.42588
# [41]	validation-rmse:6.42445
# [42]	validation-rmse:6.42370
# [43]	validation-rmse:6.42152
# [44]	validation-rmse:6.42045
# [45]	validation-rmse:6.41955
# [46]	validation-rmse:6.41782
# [47]	validation-rmse:6.41652
# [48]	validation-rmse:6.41553
# [49]	validation-rmse:6.41486
# [50]	validation-rmse:6.41290
# [51]	validation-rmse:6.41107
# [52]	validation-rmse:6.40977
# [53]	validation-rmse:6.40797
# [54]	validation-rmse:6.40719
# [55]	validation-rmse:6.40597
# [56]	validation-rmse:6.40473
# [57]	validation-rmse:6.40384
# [58]	validation-rmse:6.40309
# [59]	validation-rmse:6.40208
# [60]	validation-rmse:6.40084
# [61]	validation-rmse:6.39965
# [62]	validation-rmse:6.39859
# [63]	validation-rmse:6.39706
# [64]	validation-rmse:6.39583
# [65]	validation-rmse:6.39463
# [66]	validation-rmse:6.39417
# [67]	validation-rmse:6.39327
# [68]	validation-rmse:6.39259
# [69]	validation-rmse:6.39129
# [70]	validation-rmse:6.39020
# [71]	validation-rmse:6.38878
# [72]	validation-rmse:6.38788
# [73]	validation-rmse:6.38696
# [74]	validation-rmse:6.38614
# [75]	validation-rmse:6.38542
# [76]	validation-rmse:6.38497
# [77]	validation-rmse:6.38415
# [78]	validation-rmse:6.38332
# [79]	validation-rmse:6.38218
# [80]	validation-rmse:6.38143
# [81]	validation-rmse:6.38057
# [82]	validation-rmse:6.37986
# [83]	validation-rmse:6.37881
# [84]	validation-rmse:6.37855
# [85]	validation-rmse:6.37750
# [86]	validation-rmse:6.37712
# [87]	validation-rmse:6.37624
# [88]	validation-rmse:6.37563
# [89]	validation-rmse:6.37492
# [90]	validation-rmse:6.37446
# [91]	validation-rmse:6.37413
# [92]	validation-rmse:6.37363
# [93]	validation-rmse:6.37273
# [94]	validation-rmse:6.37217
# [95]	validation-rmse:6.37112
# [96]	validation-rmse:6.37041
# [97]	validation-rmse:6.36987
# [98]	validation-rmse:6.36892
# [99]	validation-rmse:6.36816
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [04:29:18] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
# 2025/12/12 04:29:21 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
with mlflow.start_run():

    best_params = {
        "learning_rate" : 0.1832607471256377,
        "max_depth" : 53,
        "min_child_weight" : 1.5248259426208242,
        "objective" : "reg:squarederror",
        "reg_alpha" : 0.03914337949093102,
        "reg_lambda" : 0.20458604590859147,
        "seed" : 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=100,
        evals=[(valid, "validation")],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    # Log preprocessor
    with open("preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)

    mlflow.log_artifact("preprocessor.b", artifact_path="preprocessor")

    #  ONLY ONE MODEL LOGGING — ZOOMCAMP STYLE
    result = mlflow.xgboost.log_model(
        xgb_model=booster,
        artifact_path="model",
        registered_model_name="nyc-taxi-regressor"
    )

print(result.model_uri)
# Out:
# [0]	validation-rmse:10.74801
# [1]	validation-rmse:9.63418
# [2]	validation-rmse:8.79797
# [3]	validation-rmse:8.17701
# [4]	validation-rmse:7.72271
# [5]	validation-rmse:7.39379
# [6]	validation-rmse:7.15383
# [7]	validation-rmse:6.98266
# [8]	validation-rmse:6.85603
# [9]	validation-rmse:6.76075
# [10]	validation-rmse:6.69187
# [11]	validation-rmse:6.63994
# [12]	validation-rmse:6.60079
# [13]	validation-rmse:6.57000
# [14]	validation-rmse:6.54547
# [15]	validation-rmse:6.52617
# [16]	validation-rmse:6.51044
# [17]	validation-rmse:6.49776
# [18]	validation-rmse:6.48631
# [19]	validation-rmse:6.47826
# [20]	validation-rmse:6.47111
# [21]	validation-rmse:6.46375
# [22]	validation-rmse:6.45912
# [23]	validation-rmse:6.45605
# [24]	validation-rmse:6.45350
# [25]	validation-rmse:6.45021
# [26]	validation-rmse:6.44861
# [27]	validation-rmse:6.44696
# [28]	validation-rmse:6.44587
# [29]	validation-rmse:6.44487
# [30]	validation-rmse:6.44381
# [31]	validation-rmse:6.44071
# [32]	validation-rmse:6.43863
# [33]	validation-rmse:6.43708
# [34]	validation-rmse:6.43479
# [35]	validation-rmse:6.43274
# [36]	validation-rmse:6.43126
# [37]	validation-rmse:6.42987
# [38]	validation-rmse:6.42827
# [39]	validation-rmse:6.42734
# [40]	validation-rmse:6.42588
# [41]	validation-rmse:6.42445
# [42]	validation-rmse:6.42370
# [43]	validation-rmse:6.42152
# [44]	validation-rmse:6.42045
# [45]	validation-rmse:6.41955
# [46]	validation-rmse:6.41782
# [47]	validation-rmse:6.41652
# [48]	validation-rmse:6.41553
# [49]	validation-rmse:6.41486
# [50]	validation-rmse:6.41290
# [51]	validation-rmse:6.41107
# [52]	validation-rmse:6.40977
# [53]	validation-rmse:6.40797
# [54]	validation-rmse:6.40719
# [55]	validation-rmse:6.40597
# [56]	validation-rmse:6.40473
# [57]	validation-rmse:6.40384
# [58]	validation-rmse:6.40309
# [59]	validation-rmse:6.40208
# [60]	validation-rmse:6.40084
# [61]	validation-rmse:6.39965
# [62]	validation-rmse:6.39859
# [63]	validation-rmse:6.39706
# [64]	validation-rmse:6.39583
# [65]	validation-rmse:6.39463
# [66]	validation-rmse:6.39417
# [67]	validation-rmse:6.39327
# [68]	validation-rmse:6.39259
# [69]	validation-rmse:6.39129
# [70]	validation-rmse:6.39020
# [71]	validation-rmse:6.38878
# [72]	validation-rmse:6.38788
# [73]	validation-rmse:6.38696
# [74]	validation-rmse:6.38614
# [75]	validation-rmse:6.38542
# [76]	validation-rmse:6.38497
# [77]	validation-rmse:6.38415
# [78]	validation-rmse:6.38332
# [79]	validation-rmse:6.38218
# [80]	validation-rmse:6.38143
# [81]	validation-rmse:6.38057
# [82]	validation-rmse:6.37986
# [83]	validation-rmse:6.37881
# [84]	validation-rmse:6.37855
# [85]	validation-rmse:6.37750
# [86]	validation-rmse:6.37712
# [87]	validation-rmse:6.37624
# [88]	validation-rmse:6.37563
# [89]	validation-rmse:6.37492
# [90]	validation-rmse:6.37446
# [91]	validation-rmse:6.37413
# [92]	validation-rmse:6.37363
# [93]	validation-rmse:6.37273
# [94]	validation-rmse:6.37217
# [95]	validation-rmse:6.37112
# [96]	validation-rmse:6.37041
# [97]	validation-rmse:6.36987
# [98]	validation-rmse:6.36892
# [99]	validation-rmse:6.36816
# 2025/12/12 04:33:29 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [04:33:29] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
# 2025/12/12 04:33:31 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# models:/m-aab16fc7c9674283a9f812a87a18c476
# Registered model 'nyc-taxi-regressor' already exists. Creating a new version of this model...
# Created version '1' of model 'nyc-taxi-regressor'.

# %%
result = mlflow.xgboost.log_model(
    xgb_model=booster,
    artifact_path="model",
    registered_model_name="nyc-taxi-regressor"
)

print("Model logged at:")
print(result.model_uri)
# Out:
# 2025/12/12 04:30:10 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [04:30:10] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
# 2025/12/12 04:30:12 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Model logged at:
# models:/m-c4a02c86c55a49349aa66533a8216fde
# Registered model 'nyc-taxi-regressor' already exists. Creating a new version of this model...
# Created version '2' of model 'nyc-taxi-regressor'.
