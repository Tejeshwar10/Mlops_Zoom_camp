# %%
# !python -V
# Out:
# Python 3.9.23

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
import pickle
import sklearn
import numpy as np

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-eperiment")
# Out:
# 2025/12/12 02:51:19 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/12/12 02:51:19 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# <Experiment: artifact_location='/workspaces/Mlops_Zoom_camp/02-Experiment Tracking/mlruns/1', creation_time=1765408879095, experiment_id='1', last_update_time=1765408879095, lifecycle_stage='active', name='nyc-taxi-eperiment', tags={}>

# %%
def data_read_pre_processing(file_path):
    
   
    #reading the data from the defined path
    df = pd.read_parquet(file_path)
    
    #Converting the columns to timestamp
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    
    #Calculating duration of the trip
    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df['duration'] = df.duration.apply(lambda td: td.total_seconds()/60)
    
    #filetring the data 
    df = df[(df.duration>=1) & (df.duration<=60)]
    
    return df

# %%
df_train = data_read_pre_processing('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet')

df_val = data_read_pre_processing('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-02.parquet')

# %%
import sys, sklearn
print(sys.executable)
print(sklearn.__version__)
# Out:
# /home/codespace/anaconda3/envs/exp-tracking-env/bin/python
# 1.3.0

# %%
#### Created new Feature
df_train['PU_DO'] = df_train['PULocationID'].astype(str) + '_' + df_train['DOLocationID'].astype(str)
df_val['PU_DO']  = df_val['PULocationID'].astype(str)  + '_' + df_val['DOLocationID'].astype(str)

# %%
### defining the train set 
categorical = ['PU_DO']#['PULocationID','DOLocationID']
numerical = ['trip_distance']

### Converting categorical variable into string for preprocessing
df_train[categorical] = df_train[categorical].astype(str)
train_dicts = df_train[categorical+numerical].to_dict(orient = 'records') 

### Converting categorical variable into string for preprocessing
df_val[categorical] = df_val[categorical].astype(str)
val_dicts = df_val[categorical+numerical].to_dict(orient = 'records')

# %%
### Vectoriser
dv = DictVectorizer()

# %%
## vectorizing traing Features
X_train = dv.fit_transform(train_dicts)
X_train
# Out:
# <73908x13221 sparse matrix of type '<class 'numpy.float64'>'
# 	with 147816 stored elements in Compressed Sparse Row format>

# %%
## vectorizing validation Features
X_val = dv.transform(val_dicts)
X_val
# Out:
# <61921x13221 sparse matrix of type '<class 'numpy.float64'>'
# 	with 118585 stored elements in Compressed Sparse Row format>

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# prediting the values for train set
y_predict_train = lr.predict(X_train)

# prediting the values for train set
y_predict_val = lr.predict(X_val)

# %%
import inspect
inspect.signature(mean_squared_error)
# Out:
# <Signature (y_true, y_pred, *, sample_weight=None, multioutput='uniform_average', squared=True)>

# %%
rmse = np.sqrt(mean_squared_error(y_train,y_predict_train))
rmse
# Out:
# 5.699564118198979

# %%
rmse_val =  mean_squared_error(y_val,y_predict_val,squared = False)
rmse_val
# Out:
# 7.758715209663881

# %%
with open('models/lin_reg.bin','wb') as f_out:
    pickle.dump((dv,lr),f_out)

# %% [markdown]
# # Checking a different Model like LASSO or Ridge

# %%
with mlflow.start_run():

    mlflow.set_tag("developer","Tej")

    mlflow.log_param("train-data-url","https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet")
    mlflow.log_param("validation-data-url","https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-02.parquet")
    
    alpha =0.1
    mlflow.log_param("alpha",alpha)
    lr_new = Lasso(alpha)
    lr_new.fit(X_train,y_train)
    
    y_pred_new = lr_new.predict(X_val)
    rmse = mean_squared_error(y_val,y_pred_new,squared = False)
    mlflow.log_metric("rmse",rmse)
    mlflow.log_artifact(local_path = "models/lin_reg.bin", artifact_path = "models_pickle")

# %% [markdown]
# ## Performing Hyper Parameter Tuning and loggoing the best results in ML flow

# %%
import xgboost as xgb

from hyperopt import fmin,hp,tpe,STATUS_OK, Trials
from hyperopt.pyll import scope
# Out:
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/atpe.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
train = xgb.DMatrix(X_train,label = y_train)
valid = xgb.DMatrix(X_val,label = y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model","xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params =params,
            dtrain =train,
            num_boost_round =1000,
            evals=[(valid,"validation")],
            early_stopping_rounds = 50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val,y_pred,squared = False)
        mlflow.log_metric("rmse", rmse)

    return {"loss":rmse,'status':STATUS_OK}

# %%
search_space = {
    'max_depth' :scope.int(hp.quniform('max_depth',4,100,1)),
    'learning_rate' :hp.loguniform('learning_rate',-3,0),
    'reg_alpha' :hp.loguniform('reg_alpha',-5,-1),
    'reg_lambda' :hp.loguniform('reg_lambda',-6,-1),
    'min_child_weight' :hp.loguniform('min_child_weight',-1,3),
    'objective' :'reg:squarederror',
    'seed' : 42,
}

best_result =fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
    )
# Out:
# [0]	validation-rmse:10.90308
# [1]	validation-rmse:9.87851
# [2]	validation-rmse:9.08981
# [3]	validation-rmse:8.48934
# [4]	validation-rmse:8.03668
# [5]	validation-rmse:7.69438
# [6]	validation-rmse:7.43974
# [7]	validation-rmse:7.25111
# [8]	validation-rmse:7.10945
# [9]	validation-rmse:7.00383
# [10]	validation-rmse:6.92464
# [11]	validation-rmse:6.86349
# [12]	validation-rmse:6.81710
# [13]	validation-rmse:6.78118
# [14]	validation-rmse:6.75424
# [15]	validation-rmse:6.73330
# [16]	validation-rmse:6.71464
# [17]	validation-rmse:6.70139
# [18]	validation-rmse:6.69027
# [19]	validation-rmse:6.68167
# [20]	validation-rmse:6.67268
# [21]	validation-rmse:6.66639
# [22]	validation-rmse:6.66151
# [23]	validation-rmse:6.65809
# [24]	validation-rmse:6.65376
# [25]	validation-rmse:6.64935
# [26]	validation-rmse:6.64696
# [27]	validation-rmse:6.64545
# [28]	validation-rmse:6.64456
# [29]	validation-rmse:6.64303
# [30]	validation-rmse:6.64020
# [31]	validation-rmse:6.63884
# [32]	validation-rmse:6.63780
# [33]	validation-rmse:6.63605
# [34]	validation-rmse:6.63484
# [35]	validation-rmse:6.63307
# [36]	validation-rmse:6.63199
# [37]	validation-rmse:6.63039
# [38]	validation-rmse:6.62839
# [39]	validation-rmse:6.62702
# [40]	validation-rmse:6.62560
# [41]	validation-rmse:6.62385
# [42]	validation-rmse:6.62278
# [43]	validation-rmse:6.62152
# [44]	validation-rmse:6.62041
# [45]	validation-rmse:6.61917
# [46]	validation-rmse:6.61837
# [47]	validation-rmse:6.61686
# [48]	validation-rmse:6.61620
# [49]	validation-rmse:6.61547
# [50]	validation-rmse:6.61412
# [51]	validation-rmse:6.61261
# [52]	validation-rmse:6.61173
# [53]	validation-rmse:6.61061
# [54]	validation-rmse:6.60918
# [55]	validation-rmse:6.60792
# [56]	validation-rmse:6.60740
# [57]	validation-rmse:6.60546
# [58]	validation-rmse:6.60408
# [59]	validation-rmse:6.60282
# [60]	validation-rmse:6.60213
# [61]	validation-rmse:6.60171
# [62]	validation-rmse:6.60059
# [63]	validation-rmse:6.59998
# [64]	validation-rmse:6.59928
# [65]	validation-rmse:6.59794
# [66]	validation-rmse:6.59694
# [67]	validation-rmse:6.59544
# [68]	validation-rmse:6.59475
# [69]	validation-rmse:6.59416
# [70]	validation-rmse:6.59315
# [71]	validation-rmse:6.59196
# [72]	validation-rmse:6.59108
# [73]	validation-rmse:6.59001
# [74]	validation-rmse:6.58919
# [75]	validation-rmse:6.58827
# [76]	validation-rmse:6.58760
# [77]	validation-rmse:6.58688
# [78]	validation-rmse:6.58648
# [79]	validation-rmse:6.58486
# [80]	validation-rmse:6.58372
# [81]	validation-rmse:6.58308
# [82]	validation-rmse:6.58264
# [83]	validation-rmse:6.58160
# [84]	validation-rmse:6.58049
# [85]	validation-rmse:6.57969
# [86]	validation-rmse:6.57919
# [87]	validation-rmse:6.57863
# [88]	validation-rmse:6.57806
# [89]	validation-rmse:6.57740
# [90]	validation-rmse:6.57669
# [91]	validation-rmse:6.57469
# [92]	validation-rmse:6.57392
# [93]	validation-rmse:6.57326
# [94]	validation-rmse:6.57260
# [95]	validation-rmse:6.57167
# [96]	validation-rmse:6.57075
# [97]	validation-rmse:6.57003
# [98]	validation-rmse:6.56953
# [99]	validation-rmse:6.56867
# [100]	validation-rmse:6.56776
# [101]	validation-rmse:6.56636
# [102]	validation-rmse:6.56546
# [103]	validation-rmse:6.56465
# [104]	validation-rmse:6.56452
# [105]	validation-rmse:6.56408
# [106]	validation-rmse:6.56367
# [107]	validation-rmse:6.56337
# [108]	validation-rmse:6.56271
# [109]	validation-rmse:6.56226
# [110]	validation-rmse:6.56178
# [111]	validation-rmse:6.56100
# [112]	validation-rmse:6.55981
# [113]	validation-rmse:6.55898
# [114]	validation-rmse:6.55818
# [115]	validation-rmse:6.55677
# [116]	validation-rmse:6.55622
# [117]	validation-rmse:6.55571
# [118]	validation-rmse:6.55511
# [119]	validation-rmse:6.55477
# [120]	validation-rmse:6.55410
# [121]	validation-rmse:6.55410
# [122]	validation-rmse:6.55320
# [123]	validation-rmse:6.55241
# [124]	validation-rmse:6.55159
# [125]	validation-rmse:6.55118
# [126]	validation-rmse:6.55068
# [127]	validation-rmse:6.54997
# [128]	validation-rmse:6.54956
# [129]	validation-rmse:6.54887
# [130]	validation-rmse:6.54858
# [131]	validation-rmse:6.54810
# [132]	validation-rmse:6.54749
# [133]	validation-rmse:6.54738
# [134]	validation-rmse:6.54682
# [135]	validation-rmse:6.54634
# [136]	validation-rmse:6.54575
# [137]	validation-rmse:6.54553
# [138]	validation-rmse:6.54501
# [139]	validation-rmse:6.54441
# [140]	validation-rmse:6.54415
# [141]	validation-rmse:6.54370
# [142]	validation-rmse:6.54251
# [143]	validation-rmse:6.54177
# [144]	validation-rmse:6.54137
# [145]	validation-rmse:6.54053
# [146]	validation-rmse:6.53987
# [147]	validation-rmse:6.53888
# [148]	validation-rmse:6.53852
# [149]	validation-rmse:6.53803
# [150]	validation-rmse:6.53752
# [151]	validation-rmse:6.53685
# [152]	validation-rmse:6.53623
# [153]	validation-rmse:6.53595
# [154]	validation-rmse:6.53547
# [155]	validation-rmse:6.53492
# [156]	validation-rmse:6.53468
# [157]	validation-rmse:6.53418
# [158]	validation-rmse:6.53361
# [159]	validation-rmse:6.53308
# [160]	validation-rmse:6.53283
# [161]	validation-rmse:6.53240
# [162]	validation-rmse:6.53165
# [163]	validation-rmse:6.53118
# [164]	validation-rmse:6.53053
# [165]	validation-rmse:6.53019
# [166]	validation-rmse:6.52969
# [167]	validation-rmse:6.52910
# [168]	validation-rmse:6.52823
# [169]	validation-rmse:6.52750
# [170]	validation-rmse:6.52710
# [171]	validation-rmse:6.52645
# [172]	validation-rmse:6.52560
# [173]	validation-rmse:6.52541
# [174]	validation-rmse:6.52485
# [175]	validation-rmse:6.52439
# [176]	validation-rmse:6.52434
# [177]	validation-rmse:6.52393
# [178]	validation-rmse:6.52353
# [179]	validation-rmse:6.52340
# [180]	validation-rmse:6.52301
# [181]	validation-rmse:6.52264
# [182]	validation-rmse:6.52242
# [183]	validation-rmse:6.52202
# [184]	validation-rmse:6.52136
# [185]	validation-rmse:6.52119
# [186]	validation-rmse:6.52048
# [187]	validation-rmse:6.52000
# [188]	validation-rmse:6.51937
# [189]	validation-rmse:6.51871
# [190]	validation-rmse:6.51826
# [191]	validation-rmse:6.51753
# [192]	validation-rmse:6.51721
# [193]	validation-rmse:6.51638
# [194]	validation-rmse:6.51601
# [195]	validation-rmse:6.51586
# [196]	validation-rmse:6.51504
# [197]	validation-rmse:6.51481
# [198]	validation-rmse:6.51476
# [199]	validation-rmse:6.51423
# [200]	validation-rmse:6.51350
# [201]	validation-rmse:6.51316
# [202]	validation-rmse:6.51288
# [203]	validation-rmse:6.51240
# [204]	validation-rmse:6.51182
# [205]	validation-rmse:6.51149
# [206]	validation-rmse:6.51097
# [207]	validation-rmse:6.51054
# [208]	validation-rmse:6.51020
# [209]	validation-rmse:6.50988
# [210]	validation-rmse:6.50962
# [211]	validation-rmse:6.50917
# [212]	validation-rmse:6.50879
# [213]	validation-rmse:6.50850
# [214]	validation-rmse:6.50832
# [215]	validation-rmse:6.50783
# [216]	validation-rmse:6.50733
# [217]	validation-rmse:6.50727
# [218]	validation-rmse:6.50702
# [219]	validation-rmse:6.50662
# [220]	validation-rmse:6.50620
# [221]	validation-rmse:6.50591
# [222]	validation-rmse:6.50572
# [223]	validation-rmse:6.50538
# [224]	validation-rmse:6.50504
# [225]	validation-rmse:6.50467
# [226]	validation-rmse:6.50449
# [227]	validation-rmse:6.50423
# [228]	validation-rmse:6.50406
# [229]	validation-rmse:6.50386
# [230]	validation-rmse:6.50313
# [231]	validation-rmse:6.50266
# [232]	validation-rmse:6.50264
# [233]	validation-rmse:6.50211
# [234]	validation-rmse:6.50191
# [235]	validation-rmse:6.50153
# ...
# [341]	validation-rmse:6.46863
# [342]	validation-rmse:6.46844
# [343]	validation-rmse:6.46842
# [344]	validation-rmse:6.46821
# [345]	validation-rmse:6.46805
# [346]	validation-rmse:6.46797
# [347]	validation-rmse:6.46760
# [348]	validation-rmse:6.46740
# [349]	validation-rmse:6.46725
# [350]	validation-rmse:6.46712
# [351]	validation-rmse:6.46687
# [352]	validation-rmse:6.46639
# [353]	validation-rmse:6.46623
# [354]	validation-rmse:6.46579
# [355]	validation-rmse:6.46514
# [356]	validation-rmse:6.46466
# [357]	validation-rmse:6.46421
# [358]	validation-rmse:6.46396
# [359]	validation-rmse:6.46361
# [360]	validation-rmse:6.46331
# [361]	validation-rmse:6.46326
# [362]	validation-rmse:6.46304
# [363]	validation-rmse:6.46252
# [364]	validation-rmse:6.46219
# [365]	validation-rmse:6.46079
# [366]	validation-rmse:6.45983
# [367]	validation-rmse:6.45981
# [368]	validation-rmse:6.45959
# [369]	validation-rmse:6.45935
# [370]	validation-rmse:6.45921
# [371]	validation-rmse:6.45892
# [372]	validation-rmse:6.45876
# [373]	validation-rmse:6.45845
# [374]	validation-rmse:6.45837
# [375]	validation-rmse:6.45808
# [376]	validation-rmse:6.45776
# [377]	validation-rmse:6.45750
# [378]	validation-rmse:6.45722
# [379]	validation-rmse:6.45702
# [380]	validation-rmse:6.45623
# [381]	validation-rmse:6.45602
#   0%|                                                                                                                                                              | 0/50 [00:32<?, ?trial/s, best loss=?]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 11
#       1 search_space = {
#       2     'max_depth' :scope.int(hp.quniform('max_depth',4,100,1)),
#       3     'learning_rate' :hp.loguniform('learning_rate',-3,0),
#    (...)
#       8     'seed' : 42,
#       9 }
# ---> 11 best_result =fmin(
#      12     fn=objective,
#      13     space=search_space,
#      14     algo=tpe.suggest,
#      15     max_evals=50,
#      16     trials=Trials()
#      17     )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[23], line 5, in objective(params)
#       3 mlflow.set_tag("model","xgboost")
#       4 mlflow.log_params(params)
# ----> 5 booster = xgb.train(
#       6     params =params,
#       7     dtrain =train,
#       8     num_boost_round =1000,
#       9     evals=[(valid,"validation")],
#      10     early_stopping_rounds = 50
#      11 )
#      12 y_pred = booster.predict(valid)
#      13 rmse = mean_squared_error(y_val,y_pred,squared = False)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/training.py:182, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     180         break
#     181     bst.update(dtrain, iteration=i, fobj=obj)
# --> 182     if cb_container.after_iteration(bst, i, dtrain, evals):
#     183         break
#     185 bst = cb_container.after_training(bst)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py:258, in CallbackContainer.after_iteration(self, model, epoch, dtrain, evals)
#     256 for _, name in evals:
#     257     assert name.find("-") == -1, "Dataset name should not contain `-`"
# --> 258 score: str = model.eval_set(evals, epoch, self.metric, self._output_margin)
#     259 metric_score = _parse_eval_str(score)
#     260 self._update_history(metric_score, epoch)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:2212, in Booster.eval_set(self, evals, iteration, feval, output_margin)
#    2209 evnames = c_array(ctypes.c_char_p, [c_str(d[1]) for d in evals])
#    2210 msg = ctypes.c_char_p()
#    2211 _check_call(
# -> 2212     _LIB.XGBoosterEvalOneIter(
#    2213         self.handle,
#    2214         ctypes.c_int(iteration),
#    2215         dmats,
#    2216         evnames,
#    2217         c_bst_ulong(len(evals)),
#    2218         ctypes.byref(msg),
#    2219     )
#    2220 )
#    2221 assert msg.value is not None
#    2222 res = msg.value.decode()  # pylint: disable=no-member
#
# KeyboardInterrupt:

# %%
import os, pickle
with mlflow.start_run():

    best_params = {
    "learning_rate" : 0.1832607471256377,
    "max_depth" : 53,
    "min_child_weight" : 1.5248259426208242,
    "objective" : "reg:squarederror",
    "reg_alpha" : 0.03914337949093102,
    "reg_lambda" : 0.20458604590859147,
    "seed" : 42,
    }
    mlflow.log_params(best_params)
    booster = xgb.train(
            params =best_params,
            dtrain =train,
            num_boost_round =100,
            evals=[(valid,"validation")],
            early_stopping_rounds = 50
        )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val,y_pred,squared = False)
    mlflow.log_metric("rmse", rmse)
    os.makedirs("models", exist_ok=True)
    with open('models/preprocessor.b','wb') as f_out:
       pickle.dump(dv,f_out)
    mlflow.log_artifact("models/preprocessor.b",artifact_path = "preprocessor")
    
    mlflow.xgboost.log_model(booster,name="xgb_model")
# Out:
# [0]	validation-rmse:10.74801
# [1]	validation-rmse:9.63418
# [2]	validation-rmse:8.79797
# [3]	validation-rmse:8.17701
# [4]	validation-rmse:7.72271
# [5]	validation-rmse:7.39379
# [6]	validation-rmse:7.15383
# [7]	validation-rmse:6.98266
# [8]	validation-rmse:6.85603
# [9]	validation-rmse:6.76075
# [10]	validation-rmse:6.69187
# [11]	validation-rmse:6.63994
# [12]	validation-rmse:6.60079
# [13]	validation-rmse:6.57000
# [14]	validation-rmse:6.54547
# [15]	validation-rmse:6.52617
# [16]	validation-rmse:6.51044
# [17]	validation-rmse:6.49776
# [18]	validation-rmse:6.48631
# [19]	validation-rmse:6.47826
# [20]	validation-rmse:6.47111
# [21]	validation-rmse:6.46375
# [22]	validation-rmse:6.45912
# [23]	validation-rmse:6.45605
# [24]	validation-rmse:6.45350
# [25]	validation-rmse:6.45021
# [26]	validation-rmse:6.44861
# [27]	validation-rmse:6.44696
# [28]	validation-rmse:6.44587
# [29]	validation-rmse:6.44487
# [30]	validation-rmse:6.44381
# [31]	validation-rmse:6.44071
# [32]	validation-rmse:6.43863
# [33]	validation-rmse:6.43708
# [34]	validation-rmse:6.43479
# [35]	validation-rmse:6.43274
# [36]	validation-rmse:6.43126
# [37]	validation-rmse:6.42987
# [38]	validation-rmse:6.42827
# [39]	validation-rmse:6.42734
# [40]	validation-rmse:6.42588
# [41]	validation-rmse:6.42445
# [42]	validation-rmse:6.42370
# [43]	validation-rmse:6.42152
# [44]	validation-rmse:6.42045
# [45]	validation-rmse:6.41955
# [46]	validation-rmse:6.41782
# [47]	validation-rmse:6.41652
# [48]	validation-rmse:6.41553
# [49]	validation-rmse:6.41486
# [50]	validation-rmse:6.41290
# [51]	validation-rmse:6.41107
# [52]	validation-rmse:6.40977
# [53]	validation-rmse:6.40797
# [54]	validation-rmse:6.40719
# [55]	validation-rmse:6.40597
# [56]	validation-rmse:6.40473
# [57]	validation-rmse:6.40384
# [58]	validation-rmse:6.40309
# [59]	validation-rmse:6.40208
# [60]	validation-rmse:6.40084
# [61]	validation-rmse:6.39965
# [62]	validation-rmse:6.39859
# [63]	validation-rmse:6.39706
# [64]	validation-rmse:6.39583
# [65]	validation-rmse:6.39463
# [66]	validation-rmse:6.39417
# [67]	validation-rmse:6.39327
# [68]	validation-rmse:6.39259
# [69]	validation-rmse:6.39129
# [70]	validation-rmse:6.39020
# [71]	validation-rmse:6.38878
# [72]	validation-rmse:6.38788
# [73]	validation-rmse:6.38696
# [74]	validation-rmse:6.38614
# [75]	validation-rmse:6.38542
# [76]	validation-rmse:6.38497
# [77]	validation-rmse:6.38415
# [78]	validation-rmse:6.38332
# [79]	validation-rmse:6.38218
# [80]	validation-rmse:6.38143
# [81]	validation-rmse:6.38057
# [82]	validation-rmse:6.37986
# [83]	validation-rmse:6.37881
# [84]	validation-rmse:6.37855
# [85]	validation-rmse:6.37750
# [86]	validation-rmse:6.37712
# [87]	validation-rmse:6.37624
# [88]	validation-rmse:6.37563
# [89]	validation-rmse:6.37492
# [90]	validation-rmse:6.37446
# [91]	validation-rmse:6.37413
# [92]	validation-rmse:6.37363
# [93]	validation-rmse:6.37273
# [94]	validation-rmse:6.37217
# [95]	validation-rmse:6.37112
# [96]	validation-rmse:6.37041
# [97]	validation-rmse:6.36987
# [98]	validation-rmse:6.36892
# [99]	validation-rmse:6.36816
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [02:53:13] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
# 2025/12/12 02:53:18 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
with mlflow.start_run():

    best_params = {
        "learning_rate" : 0.1832607471256377,
        "max_depth" : 53,
        "min_child_weight" : 1.5248259426208242,
        "objective" : "reg:squarederror",
        "reg_alpha" : 0.03914337949093102,
        "reg_lambda" : 0.20458604590859147,
        "seed" : 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=100,
        evals=[(valid, "validation")],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    # Log preprocessor inside artifacts
    with open("preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)

    mlflow.log_artifact("preprocessor.b", artifact_path="preprocessor")
    
    result = mlflow.xgboost.log_model(
    xgb_model=booster,
    artifact_path="model",
    registered_model_name="nyc-taxi-regressor"
    )

    print("Model logged at:")
    print(result.model_uri)
# Out:
# [0]	validation-rmse:10.74801
# [1]	validation-rmse:9.63418
# [2]	validation-rmse:8.79797
# [3]	validation-rmse:8.17701
# [4]	validation-rmse:7.72271
# [5]	validation-rmse:7.39379
# [6]	validation-rmse:7.15383
# [7]	validation-rmse:6.98266
# [8]	validation-rmse:6.85603
# [9]	validation-rmse:6.76075
# [10]	validation-rmse:6.69187
# [11]	validation-rmse:6.63994
# [12]	validation-rmse:6.60079
# [13]	validation-rmse:6.57000
# [14]	validation-rmse:6.54547
# [15]	validation-rmse:6.52617
# [16]	validation-rmse:6.51044
# [17]	validation-rmse:6.49776
# [18]	validation-rmse:6.48631
# [19]	validation-rmse:6.47826
# [20]	validation-rmse:6.47111
# [21]	validation-rmse:6.46375
# [22]	validation-rmse:6.45912
# [23]	validation-rmse:6.45605
# [24]	validation-rmse:6.45350
# [25]	validation-rmse:6.45021
# [26]	validation-rmse:6.44861
# [27]	validation-rmse:6.44696
# [28]	validation-rmse:6.44587
# [29]	validation-rmse:6.44487
# [30]	validation-rmse:6.44381
# [31]	validation-rmse:6.44071
# [32]	validation-rmse:6.43863
# [33]	validation-rmse:6.43708
# [34]	validation-rmse:6.43479
# [35]	validation-rmse:6.43274
# [36]	validation-rmse:6.43126
# [37]	validation-rmse:6.42987
# [38]	validation-rmse:6.42827
# [39]	validation-rmse:6.42734
# [40]	validation-rmse:6.42588
# [41]	validation-rmse:6.42445
# [42]	validation-rmse:6.42370
# [43]	validation-rmse:6.42152
# [44]	validation-rmse:6.42045
# [45]	validation-rmse:6.41955
# [46]	validation-rmse:6.41782
# [47]	validation-rmse:6.41652
# [48]	validation-rmse:6.41553
# [49]	validation-rmse:6.41486
# [50]	validation-rmse:6.41290
# [51]	validation-rmse:6.41107
# [52]	validation-rmse:6.40977
# [53]	validation-rmse:6.40797
# [54]	validation-rmse:6.40719
# [55]	validation-rmse:6.40597
# [56]	validation-rmse:6.40473
# [57]	validation-rmse:6.40384
# [58]	validation-rmse:6.40309
# [59]	validation-rmse:6.40208
# [60]	validation-rmse:6.40084
# [61]	validation-rmse:6.39965
# [62]	validation-rmse:6.39859
# [63]	validation-rmse:6.39706
# [64]	validation-rmse:6.39583
# [65]	validation-rmse:6.39463
# [66]	validation-rmse:6.39417
# [67]	validation-rmse:6.39327
# [68]	validation-rmse:6.39259
# [69]	validation-rmse:6.39129
# [70]	validation-rmse:6.39020
# [71]	validation-rmse:6.38878
# [72]	validation-rmse:6.38788
# [73]	validation-rmse:6.38696
# [74]	validation-rmse:6.38614
# [75]	validation-rmse:6.38542
# [76]	validation-rmse:6.38497
# [77]	validation-rmse:6.38415
# [78]	validation-rmse:6.38332
# [79]	validation-rmse:6.38218
# [80]	validation-rmse:6.38143
# [81]	validation-rmse:6.38057
# [82]	validation-rmse:6.37986
# [83]	validation-rmse:6.37881
# [84]	validation-rmse:6.37855
# [85]	validation-rmse:6.37750
# [86]	validation-rmse:6.37712
# [87]	validation-rmse:6.37624
# [88]	validation-rmse:6.37563
# [89]	validation-rmse:6.37492
# [90]	validation-rmse:6.37446
# [91]	validation-rmse:6.37413
# [92]	validation-rmse:6.37363
# [93]	validation-rmse:6.37273
# [94]	validation-rmse:6.37217
# [95]	validation-rmse:6.37112
# [96]	validation-rmse:6.37041
# [97]	validation-rmse:6.36987
# [98]	validation-rmse:6.36892
# [99]	validation-rmse:6.36816
# 2025/12/12 03:10:26 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [03:10:26] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
# 2025/12/12 03:10:29 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Model logged at:
# models:/m-600597f14d494833bfc6190b02c02794
# Registered model 'nyc-taxi-regressor' already exists. Creating a new version of this model...
# Created version '7' of model 'nyc-taxi-regressor'.

# %%
result = mlflow.xgboost.log_model(
    xgb_model=booster,
    artifact_path="model",
    registered_model_name="nyc-taxi-regressor"
)

print("Model logged at:")
print(result.model_uri)
# Out:
# 2025/12/12 03:07:32 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [03:07:32] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
# 2025/12/12 03:07:35 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Model logged at:
# models:/m-147b454879804007b41e2b03166b0478
# Registered model 'nyc-taxi-regressor' already exists. Creating a new version of this model...
# Created version '6' of model 'nyc-taxi-regressor'.
